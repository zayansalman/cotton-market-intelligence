# %% [markdown]
# # Cotton Market Intelligence – Exploration
#
# This notebook demonstrates the core cotton-market-intelligence tool:
#
# - Loads daily cotton prices and macro series
# - Computes benchmarks (nominal vs real prices, percentiles, z-scores)
# - Runs the buy-signal engine for an example mill
# - Visualizes signals and suggested quantities over time.
